# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.config("spark.jars", "C:/Users/KIIT/Downloads/mysql-connector-j-9.0.0/mysql-connector-j-9.0.0/mysql-connector-j-9.0.0.jar") \
    .master("local").appName("PySpark_MySQL_test").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pyspark
#       2 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder.config("spark.jars", "C:/Users/KIIT/Downloads/mysql-connector-j-9.0.0/mysql-connector-j-9.0.0/mysql-connector-j-9.0.0.jar") \
# ----> 4     .master("local").appName("PySpark_MySQL_test").getOrCreate()
#
# File ~\anaconda3\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# ...

# %%
# MySQL connection properties
url = "jdbc:mysql://localhost:3306/Brazil_ECom"
properties = {
    "user": "username",
    "password": "password",
    "driver": "com.mysql.cj.jdbc.Driver"
}

# Read data from MySQL table into a Spark DataFrame
df = spark.read.jdbc(url=url, table="order_items_dataset", properties=properties)

# Show the data
df.show(10)
