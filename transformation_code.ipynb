# %% [markdown]
# importing essential libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# reading files in form of dataframes

# %%
customer_ds = pd.read_csv("dataset\olist_customers_dataset.csv")
geolocation_ds = pd.read_csv("dataset\olist_geolocation_dataset.csv")
order_items_ds = pd.read_csv("dataset\olist_order_items_dataset.csv")
order_payments_ds = pd.read_csv("dataset\olist_order_payments_dataset.csv")
orders_ds = pd.read_csv("dataset\olist_orders_dataset.csv")
products_ds = pd.read_csv("dataset\olist_products_dataset.csv")
sellers_ds = pd.read_csv("dataset\olist_sellers_dataset.csv")
products_name_ds = pd.read_csv("dataset\product_category_name_translation.csv")

# %%
orders_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_ds['order_delivered_carrier_date'] = pd.to_datetime(orders_ds['order_delivered_carrier_date'])
orders_ds['order_delivered_customer_date'] = pd.to_datetime(orders_ds['order_delivered_customer_date'])
orders_ds['order_estimated_delivery_date'] = pd.to_datetime(orders_ds['order_estimated_delivery_date'])
orders_ds['order_approved_at'] = pd.to_datetime(orders_ds['order_approved_at'])
orders_ds['order_purchase_timestamp'] = pd.to_datetime(orders_ds['order_purchase_timestamp'])

order_items_ds['shipping_limit_date'] = pd.to_datetime(order_items_ds['shipping_limit_date'])

# %%
order_items_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
datetime_dim_order_ds = (orders_ds[['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date']]).reset_index(drop=True)

# %%
datetime_dim_order_ds['order_purchase_timestamp'] = datetime_dim_order_ds['order_purchase_timestamp']
datetime_dim_order_ds['order_purchase_timestamp_hour'] = datetime_dim_order_ds['order_purchase_timestamp'].dt.hour
datetime_dim_order_ds['order_purchase_timestamp_day'] = datetime_dim_order_ds['order_purchase_timestamp'].dt.day
datetime_dim_order_ds['order_purchase_timestamp_month'] = datetime_dim_order_ds['order_purchase_timestamp'].dt.month
datetime_dim_order_ds['order_purchase_timestamp_year'] = datetime_dim_order_ds['order_purchase_timestamp'].dt.year
datetime_dim_order_ds['order_purchase_timestamp_weekday'] = datetime_dim_order_ds['order_purchase_timestamp'].dt.weekday

datetime_dim_order_ds['order_approved_at'] = datetime_dim_order_ds['order_approved_at']
datetime_dim_order_ds['order_approved_at_hour'] = datetime_dim_order_ds['order_approved_at'].dt.hour
datetime_dim_order_ds['order_approved_at_day'] = datetime_dim_order_ds['order_approved_at'].dt.day
datetime_dim_order_ds['order_approved_at_month'] = datetime_dim_order_ds['order_approved_at'].dt.month
datetime_dim_order_ds['order_approved_at_year'] = datetime_dim_order_ds['order_approved_at'].dt.year
datetime_dim_order_ds['order_approved_at_weekday'] = datetime_dim_order_ds['order_approved_at'].dt.weekday

datetime_dim_order_ds['order_delivered_carrier_date'] = datetime_dim_order_ds['order_delivered_carrier_date']
datetime_dim_order_ds['order_delivered_carrier_date_hour'] = datetime_dim_order_ds['order_delivered_carrier_date'].dt.hour
datetime_dim_order_ds['order_delivered_carrier_date_day'] = datetime_dim_order_ds['order_delivered_carrier_date'].dt.day
datetime_dim_order_ds['order_delivered_carrier_date_month'] = datetime_dim_order_ds['order_delivered_carrier_date'].dt.month
datetime_dim_order_ds['order_delivered_carrier_date_year'] = datetime_dim_order_ds['order_delivered_carrier_date'].dt.year
datetime_dim_order_ds['order_delivered_carrier_date_weekday'] = datetime_dim_order_ds['order_delivered_carrier_date'].dt.weekday

datetime_dim_order_ds['order_delivered_customer_date'] = datetime_dim_order_ds['order_delivered_customer_date']
datetime_dim_order_ds['order_delivered_customer_date_hour'] = datetime_dim_order_ds['order_delivered_customer_date'].dt.hour
datetime_dim_order_ds['order_delivered_customer_date_day'] = datetime_dim_order_ds['order_delivered_customer_date'].dt.day
datetime_dim_order_ds['order_delivered_customer_date_month'] = datetime_dim_order_ds['order_delivered_customer_date'].dt.month
datetime_dim_order_ds['order_delivered_customer_date_year'] = datetime_dim_order_ds['order_delivered_customer_date'].dt.year
datetime_dim_order_ds['order_delivered_customer_date_weekday'] = datetime_dim_order_ds['order_delivered_customer_date'].dt.weekday

datetime_dim_order_ds['order_estimated_delivery_date'] = datetime_dim_order_ds['order_estimated_delivery_date']
datetime_dim_order_ds['order_estimated_delivery_date_hour'] = datetime_dim_order_ds['order_estimated_delivery_date'].dt.hour
datetime_dim_order_ds['order_estimated_delivery_date_day'] = datetime_dim_order_ds['order_estimated_delivery_date'].dt.day
datetime_dim_order_ds['order_estimated_delivery_date_month'] = datetime_dim_order_ds['order_estimated_delivery_date'].dt.month
datetime_dim_order_ds['order_estimated_delivery_date_year'] = datetime_dim_order_ds['order_estimated_delivery_date'].dt.year
datetime_dim_order_ds['order_estimated_delivery_date_weekday'] = datetime_dim_order_ds['order_estimated_delivery_date'].dt.weekday

datetime_dim_order_ds['datetime_id'] = datetime_dim_order_ds.index

datetime_dim_order_ds = datetime_dim_order_ds[['datetime_id', 
                             'order_purchase_timestamp',
                             'order_purchase_timestamp_day', 
                             'order_purchase_timestamp_hour', 
                             'order_purchase_timestamp_year', 
                             'order_purchase_timestamp_weekday',
                             'order_approved_at', 
                             'order_approved_at_hour', 
                             'order_approved_at_day', 
                             'order_approved_at_month', 
                             'order_approved_at_year', 
                             'order_approved_at_weekday',
                             'order_delivered_carrier_date',
                             'order_delivered_carrier_date_hour',
                             'order_delivered_carrier_date_day',
                             'order_delivered_carrier_date_year',
                             'order_delivered_carrier_date_weekday',
                             'order_delivered_customer_date',
                             'order_delivered_customer_date_hour',
                             'order_delivered_customer_date_day',
                             'order_delivered_customer_date_year',
                             'order_delivered_customer_date_weekday',
                             'order_estimated_delivery_date',
                             'order_estimated_delivery_date_hour',
                             'order_estimated_delivery_date_day',
                             'order_estimated_delivery_date_year',
                             'order_estimated_delivery_date_weekday']]
#
datetime_dim_order_ds.head()
# Out:
#    datetime_id order_purchase_timestamp  order_purchase_timestamp_day  \
# 0            0      2017-10-02 10:56:33                             2
# 1            1      2018-07-24 20:41:37                            24
# 2            2      2018-08-08 08:38:49                             8
# 3            3      2017-11-18 19:28:06                            18
# 4            4      2018-02-13 21:18:39                            13
#
#    order_purchase_timestamp_hour  order_purchase_timestamp_year  \
# 0                             10                           2017
# 1                             20                           2018
# 2                              8                           2018
# 3                             19                           2017
# 4                             21                           2018
#
#    order_purchase_timestamp_weekday   order_approved_at  \
# 0                                 0 2017-10-02 11:07:15
# ...
